# %% [markdown]
# # Exercise: Iris Dataset
# Now that you have a good understanding of exploritory data analysis and it's importance, it's time to put your knowledge to a more practical example. We'll be focusing on a iris public dataset from the scikit-learn library.
#
# Our main objectives for this dataset are:
# 1. Load the iris dataset into a pandas dataframe
# 2. Create a table summary of the features and target values
# 3. Create a histogram of all the features and target
# 4. Create a correlation matrix of the features and target
# 5. Create scatter plots of all the features and target

# %%
import pandas as pd
import sklearn
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
# Load in the iris dataset
iris = datasets.load_iris()

# %%
# For clarity, the iris dataset is a dictionary with the data and target separated
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
# Create the iris `data` dataset as a dataframe and name the columns with `feature_names`
df = pd.DataFrame(iris['data'], columns=iris['feature_names'])

# Include the target as well
df['target'] = iris['target']

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Loading iris dataset, use `as_frame=True` to return it as a dataframe
iris = datasets.load_iris(as_frame=True)

# %%
# For clarity, the iris dataset is a dictionary with the data and target separated
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
# Create the iris dataset as a dataframe, it'll be the `frame` key
df = iris['frame']

# %%
# Check your dataframe by `.head()`
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Simple table summary
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
# Histogram to show all the data distributions including the target
df.hist(figsize=(12, 7));

# %%
# Investigate to see if any data are correlated positively or negatively
df.corr().style.background_gradient("Blues")
# Out:
# <style type="text/css">
# #T_09abb_row0_col0, #T_09abb_row1_col1, #T_09abb_row2_col2, #T_09abb_row3_col3, #T_09abb_row4_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_09abb_row0_col1 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_09abb_row0_col2 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_09abb_row0_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_09abb_row0_col4 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_09abb_row1_col0, #T_09abb_row1_col2, #T_09abb_row1_col3, #T_09abb_row1_col4, #T_09abb_row2_col1, #T_09abb_row4_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_09abb_row2_col0 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_09abb_row2_col3, #T_09abb_row3_col2 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_09abb_row2_col4, #T_09abb_row4_col2 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_09abb_row3_col0 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_09abb_row3_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_09abb_row3_col4 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_09abb_row4_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_09abb_row4_col3 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_09abb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09abb_level0_col0" class="col_heading level0 col0" >sepal length (cm)</th>
#       <th id="T_09abb_level0_col1" class="col_heading level0 col1" >sepal width (cm)</th>
#       <th id="T_09abb_level0_col2" class="col_heading level0 col2" >petal length (cm)</th>
#       <th id="T_09abb_level0_col3" class="col_heading level0 col3" >petal width (cm)</th>
#       <th id="T_09abb_level0_col4" class="col_heading level0 col4" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09abb_level0_row0" class="row_heading level0 row0" >sepal length (cm)</th>
#       <td id="T_09abb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_09abb_row0_col1" class="data row0 col1" >-0.117570</td>
#       <td id="T_09abb_row0_col2" class="data row0 col2" >0.871754</td>
#       <td id="T_09abb_row0_col3" class="data row0 col3" >0.817941</td>
#       <td id="T_09abb_row0_col4" class="data row0 col4" >0.782561</td>
#     </tr>
#     <tr>
#       <th id="T_09abb_level0_row1" class="row_heading level0 row1" >sepal width (cm)</th>
#       <td id="T_09abb_row1_col0" class="data row1 col0" >-0.117570</td>
#       <td id="T_09abb_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_09abb_row1_col2" class="data row1 col2" >-0.428440</td>
#       <td id="T_09abb_row1_col3" class="data row1 col3" >-0.366126</td>
#       <td id="T_09abb_row1_col4" class="data row1 col4" >-0.426658</td>
#     </tr>
#     <tr>
#       <th id="T_09abb_level0_row2" class="row_heading level0 row2" >petal length (cm)</th>
#       <td id="T_09abb_row2_col0" class="data row2 col0" >0.871754</td>
#       <td id="T_09abb_row2_col1" class="data row2 col1" >-0.428440</td>
#       <td id="T_09abb_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_09abb_row2_col3" class="data row2 col3" >0.962865</td>
#       <td id="T_09abb_row2_col4" class="data row2 col4" >0.949035</td>
#     </tr>
#     <tr>
#       <th id="T_09abb_level0_row3" class="row_heading level0 row3" >petal width (cm)</th>
#       <td id="T_09abb_row3_col0" class="data row3 col0" >0.817941</td>
#       <td id="T_09abb_row3_col1" class="data row3 col1" >-0.366126</td>
#       <td id="T_09abb_row3_col2" class="data row3 col2" >0.962865</td>
#       <td id="T_09abb_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_09abb_row3_col4" class="data row3 col4" >0.956547</td>
#     </tr>
#     <tr>
#       <th id="T_09abb_level0_row4" class="row_heading level0 row4" >target</th>
#       <td id="T_09abb_row4_col0" class="data row4 col0" >0.782561</td>
#       <td id="T_09abb_row4_col1" class="data row4 col1" >-0.426658</td>
#       <td id="T_09abb_row4_col2" class="data row4 col2" >0.949035</td>
#       <td id="T_09abb_row4_col3" class="data row4 col3" >0.956547</td>
#       <td id="T_09abb_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Scatter Plot Of Features
# Create a scatter plot of the four features against eachother to visualize the results from the correlation matrix
# 1. `sepal length (cm)` vs. `sepal width (cm)`
# 2. `sepal length (cm)` vs. `petal length (cm)`
# 3. `sepal length (cm)` vs. `petal width (cm)`
# 4. `sepal width (cm)` vs. `petal length (cm)`
# 5. `sepal width (cm)` vs. `petal width (cm)`
# 6. `petal length (cm)` vs. `petal width (cm)`

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 8))

df.plot(ax=axes[0,0], x='sepal length (cm)', y='sepal width (cm)', kind='scatter')
df.plot(ax=axes[0,1], x='sepal length (cm)', y='petal length (cm)', kind='scatter')
df.plot(ax=axes[0,2], x='sepal length (cm)', y='petal width (cm)', kind='scatter')
df.plot(ax=axes[1,0], x='sepal width (cm)', y='petal length (cm)', kind='scatter')
df.plot(ax=axes[1,1], x='sepal width (cm)', y='petal width (cm)', kind='scatter')
df.plot(ax=axes[1,2], x='sepal length (cm)', y='petal width (cm)', kind='scatter')

plt.show()

# %% [markdown]
# # Scatter Plot Of Features And Target
# Create a scatter plot of the four features against the target
# 1. `sepal length (cm)`
# 2. `sepal width (cm)`
# 3. `petal length (cm)`
# 4. `petal width (cm)`

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))
df.plot(ax=axes[0, 0], x='sepal length (cm)', y='target', kind='scatter')
df.plot(ax=axes[0, 1], x='sepal width (cm)', y='target', kind='scatter')
df.plot(ax=axes[1, 0], x='petal length (cm)', y='target', kind='scatter')
df.plot(ax=axes[1, 1], x='petal width (cm)', y='target', kind='scatter')
plt.show()
